# %% [markdown]
# Crea una clase Racional que permita trabajar con números racionales (fracciones). Incluye los siguientes métodos: constructores (por defecto y parametrizado), accedentes, leer(), suma, resta, multiplicación, división, comparaciones, copia() y print().

# %%
#1
class NumeroComplejo:
  # Definimos el constructor
  def __init__(self, _x, _y):
 
    self.x = _x
    self.y = _y

  def imprimir(self):
    print("El valor de x es: " + str(self.x))
    print("El valor de y es: " + str(self.y))

  def __str__(self):
    return "(" + str(self.x) + ", " + str(self.y) + ")"

  def son_iguales(self, c2):
    if self.x == c2.x and self.y == c2.y:
      return True
    return False

  def sumar_complejos(self, c2):
    a = self.x + c2.x
    b = self.y + c2.y
    return NumeroComplejo(a, b)

  def restar_complejos(self, c2):
    a = self.x - c2.x
    b = self.y - c2.y
    return NumeroComplejo(a, b)

  def multiplicar_complejos(self, c2):
    a = self.x * c2.x
    b = self.y * c2.y
    return NumeroComplejo(a, b)

  def dividir_complejos(self, c2):
    a = self.x / c2.x
    b = self.y / c2.y
    return NumeroComplejo(a, b)

nc1 = NumeroComplejo(4, 4)
nc2 = NumeroComplejo(3, 6)
r = nc1.sumar_complejos(nc2)
r2 = nc1.restar_complejos(nc2)
r3 = nc1.multiplicar_complejos(nc2)
r4 = nc1.dividir_complejos(nc2)

print(r)
print(r2)
print(r3)
print(r4)
# Out:
# (7, 10)
# (1, -2)
# (12, 24)
# (1.3333333333333333, 0.6666666666666666)

# %% [markdown]
# Crea una clase Racional que permita trabajar con números racionales (fracciones) Incluye los siguientes métodos: constructores (por defecto y parametrizado), accedentes, leer(), suma, resta, multiplicación, división, comparaciones, copia() y print()

# %%
#2
#metodo

def __init__(self, numerador, denominador):
      self.num = numerador
      self.den = denominador

def mostrar(self):
        print(self.num,"/",self.den)

def __add__(self,otraFraccion):
        nuevoNum=self.num*otraFraccion.den+self.den*otraFraccion.num
        nuevoDen=self.den*otraFraccion.den
        comun=(nuevoNum,nuevoDen)
        return otraFraccion(nuevoNum//comun.nuevoDen//comun)


print("f3")
f1=otraFraccion(1/4)
f2=otraFraccion(1/2)
f3=f1+f2
# Out:
# f3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4dc8a45d6ecb> in <module>
#      17
#      18 print("f3")
# ---> 19 f1= otraFraccion(1/4)
#      20 f2= otraFraccion(1/2)
#      21 f3=f1+f2
#
# NameError: name 'otraFraccion' is not defined

# %% [markdown]
# Desarrolla una clase Cancion con los siguientes atributos:
#
#  titulo: una variable String que guarda el título de la canción.
#
#  autor: una variable String que guarda el autor de la canción y los siguientes métodos:
#
#  Cancion(String, String): constructor que recibe como parámetros el título y el autor de la canción (por este orden).
#
#  Cancion(): constructor predeterminado que inicializa el título y el autor a cadenas vacías.
#
#  dameTitulo(): devuelve el título de la canción.
#
#  dameAutor(): devuelve el autor de la canción.
#
#  ponTitulo(String): establece el título de la canción.
#
#  ponAutor(String): establece el autor de la canción.

# %%
#12
class Cancion():
  def __init__(self, p_titulo, p_autor):
    self.titulo = p_titulo
    self.autor = p_autor

    #Metodos

    def dameTitulo (self):
      titulo = self.p_titulo
      return titulo

    def dameAutor (self):
      autor = self.p_autor
      return autor

    def ponTitulo ():
      return p_titulo
    
    def ponAutor ():
      return p_autor


    def MostrarCancion(self):
      print("\ntitulo: "+self.p_titulo()+"\nautor: "+self.p_autor())

p_titulo = (input("Titulo : "))
p_autor = (input("Autor : "))

tema = Cancion(p_titulo, p_autor)
print("El titulo de la canción es {} y el autor es {} ".format(tema.titulo,tema.autor))
# Out:
# Titulo : Te va a doler
# Autor : Maelo Ruiz
# El titulo de la canción es Te va a doler y el autor es Maelo Ruiz
