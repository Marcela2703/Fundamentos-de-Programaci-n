# %% [markdown]
# Descripción del Enunciado:  Para un estudiante leer su nombre,  las 3 notas de los parciales
# y calcular su nota definitiva e informa si aprobó o reprobo.  La nota definitiva se calcula por
# promedio
# Autor: Grupo FP Noche
# Fecha: 31_08_2022
# Versión: 1.0

# %%
# Declaración de variables
var_ent_cad_nombreEstudiante= ""
var_ent_float_nota_PP=0.0
var_ent_float_nota_SP=0.0
var_ent_float_nota_TP=0.0
var_proSal_float_notaDef=0.0 # Variable que almacena la nota definitiva
var_proSal_cad_concepto = ""

# %%
# Captura de datos
var_ent_cad_nombreEstudiante= input("Nombre Estudiante :")
var_ent_float_nota_PP= float(input("Primer Parcial :"))
var_ent_float_nota_SP= float(input("Segundo Parcial :"))
var_ent_float_nota_TP= float(input("Tercer Parcial :"))
# Out:
# Nombre Estudiante :Marcela Chica
# Primer Parcial :3.5
# Segundo Parcial :4.0
# Tercer Parcial :3.5

# %%
# Procesos
var_ent_float_nota_TP = (var_ent_float_nota_PP+var_ent_float_nota_SP+var_ent_float_nota_TP)/3

# Saber si el estudiante aprobo
if(var_proSal_float_notaDef>=3.0):
  var_proSal_cad_concepto = "Aprobó - Te promueves"
else(var_proSal_float_notaDef<=3.0)
  var_proSal_cad_concepto = "Reprobó - Sigue Intentándolo"
# Out:
#   File "<ipython-input-2-bca22c673dc7>", line 7
#     else(var_proSal_float_notaDef<=3.0)
#         ^
# SyntaxError: invalid syntax

# %%
# Salidas
print("La nota definitiva de ",var_ent_cad_nombreEstudiante +" es : ",str(var_ent_float_nota_TP) + " Concepto : ",var_proSal_cad_concepto )
# Out:
# La nota definitiva de  Marcela Chica es :  3.6666666666666665 Concepto :  Reprobó - Sigue Intentándolo
