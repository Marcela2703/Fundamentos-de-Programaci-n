# %%
#include<stdio.h>
#include<conio.h>

void cargar(char palabra[40])
{
    printf("Ingrese una palabra:");
    gets(palabra);
}

int cantidadDePosiciones(ord[10])
{
    int cant=0;
    int x=0;
    while(posicion[x]!='\0')
    {
        if (posicion[x]=='a' || palabra[x]=='e' || palabra[x]=='i' || palabra[x]=='o' || palabra[x]=='u' ||
            palabra[x]=='A' || palabra[x]=='E' || palabra[x]=='I' || palabra[x]=='O' || palabra[x]=='U')
        {
            cant++;
        }
        x++;
    }
    return cant;
}


int main()
{
    ord[10];
    cargar(pos);
    printf("La cantidad de vocales que tiene la palabra: %s es de %i",pal, cantidadDeVocales(pal));
    getch();
    return 0;
}
# Out:
#   File "<ipython-input-1-faeff8158b28>", line 4
#     void cargar(char palabra[40])
#               ^
# SyntaxError: invalid syntax
