# %% [markdown]
# Nombre: Marcela Chica

# %%
# Declarar variables
fac= 1
num=0
# Lecturas
num= int(input("Digite nùmero : "))
# Calcular los procesos
for i in range(1,num+1):
  fac=fac*i
 
# Imprimir resultados
print("El factorial es: ", str(fac))
# Out:
# Digite nùmero : 5
# El factorial es:  120

# %%
import math  #Forma facil de calcular el proceso
num= int(input("Digite nùmero : "))
print("El factorial es: ",str(math.factorial(num)))
# Out:
# Digite nùmero : 5
# El factorial es:  120

# %%
def miFactorial():
  fac= 1
  num=0
  # Lecturas
  num= int(input("Digite nùmero : "))
  # Calcular los procesos
  for i in range(1,num+1):
    fac=fac*i
  
  # Imprimir resultados
  print("El factorial es: ", str(fac))
# Llamado de mi función
miFactorial()
miFactorial()
# Out:
# Digite nùmero : 5
# El factorial es:  120
# Digite nùmero : 25
# El factorial es:  15511210043330985984000000
