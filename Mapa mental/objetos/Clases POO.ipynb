# %%
# Construir
class Cachorro():
  # Metodo Constructor
  def __init__(self,p_color,p_raza,p_nombre):
    self.color= p_color
    self.raza= p_raza
    self.nombre= p_nombre

# Metodo Principal
p_color= input("Color: ")
p_raza= input("Raza: ")
p_nombre= input("Nombre: ")

perrito =Cachorro(p_color,p_raza,p_nombre)
print("Este es un cachorro sin dueño y la raza{} y es de color{}y se llama {}".forma(perrito.raza,perrito.color,perrito.nombre))
# Out:
# Color: k
# Raza: n
# Nombre: k
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-71c19784652c> in <module>
#      13
#      14 perrito =Cachorro(p_color,p_raza,p_nombre)
# ---> 15 print("Este es un cachorro sin dueño y la raza{} y es de color{}y se llama {}".forma(perrito.raza,perrito.color,perrito.nombre))
#
# AttributeError: 'str' object has no attribute 'forma'

# %%
class C_Rectangulo:
  def __init__(self,p_ancho,p_alto):
    self.at_ancho=p_ancho
    self.at_alto=p_alto


  def m_area(self):
    area=self.at_alto*self.at_ancho
    return area


  def m_perimetro(self):
    perimetro=(self.at_alto*2)+(self.at_ancho*2)
    return perimetro


r1=C_Rectangulo(4,2)
area=r1.m_area()
perimetro=r1.m_perimetro()
print("El área es: ",area)
print("El perimetro es: ",perimetro)

p_ancho=int(input("Ancho: "))
p_alto=int(input("Alto: "))

obj_rect2=C_Rectangulo(p_ancho,p_alto)

print("El area es: ",obj_rect2.m_area())
print("El perimetro es: ",obj_rect2.m_perimetro())
# Out:
# El área es:  8
# El perimetro es:  12
# Ancho: 3
# Alto: 7
# El area es:  21
# El perimetro es:  20

# %%
class C_Rectangulo:
  def __init__(self,p_ancho,p_alto,p_largo):
    self.at_ancho=p_ancho
    self.at_alto=p_alto
    self.at_largo=p_largo


  def m_area(self):
    area=self.at_alto*self.at_ancho
    return area


  def m_perimetro(self):
    perimetro=(self.at_alto*2)+(self.at_ancho*2)
    return perimetro

  def m_profundidad(self):
    profundidad=self.at_alto*self.at_ancho*self.at_largo


r1=C_Rectangulo(4,2)
area=r1.m_area()
perimetro=r1.m_perimetro()
print("El área es: ",area)
print("El perimetro es: ",perimetro)
print("La profundidad es: ", profundidad)

p_ancho=int(input("Ancho: "))
p_alto=int(input("Alto: "))

obj_rect2=C_Rectangulo(p_ancho,p_alto)

print("El area es: ",obj_rect2.m_area())
print("El perimetro es: ",obj_rect2.m_perimetro())
