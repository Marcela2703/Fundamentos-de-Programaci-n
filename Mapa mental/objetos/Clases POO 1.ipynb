# %%
class Complejo{                                                 
                                                
        class// declaración de números complejos
        Complejo c1 = Complejo(1.0, 1.0);
        Complejo c2 = Complejo(2.0, 2.0);
        Complejo c3;
        // operaciones aritmeticas
        c3 = c1.sumar(c2);
        sistema(c1 + " + " + c2 + " = " + c3);
        c3 = c1.restar(c2);
        sistema(c1 + " - " + c2 + " = " + c3);
        c3 = c1.dividir(c2);
        sistema(c1 + " / " + c2 + " = " + c3);
        c3 = c1.multiplicar(c2);
        sistema(c1 + " * " + c2 + " = " + c3);
        c3 = c1.multiplicar(3.5);
        sistema(c1 + " * 3.5 = " + c3);
        if (c2.equals(c3)) {
            sistema(c2 + " igual que " + c3);
        } else {
            sistema(c2 + " distinto que " + c3);
        }
}
# Out:
#   File "<ipython-input-3-025cf4a0411c>", line 1
#     class Complejo{
#                   ^
# SyntaxError: invalid syntax
