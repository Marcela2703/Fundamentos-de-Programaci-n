# %%
# Área de declaración de variables

# %%
# Primer ciclo
for x in range(10):
   print("Usted va en la vuelta número : ",x)
# Out:
# Usted va en la vuelta número :  0
# Usted va en la vuelta número :  1
# Usted va en la vuelta número :  2
# Usted va en la vuelta número :  3
# Usted va en la vuelta número :  4
# Usted va en la vuelta número :  5
# Usted va en la vuelta número :  6
# Usted va en la vuelta número :  7
# Usted va en la vuelta número :  8
# Usted va en la vuelta número :  9

# %%
# Segundo ciclo pidiendo inicio y fin

# %%
# Ciclo para leyendo inicio y el fin
inicio = int(input("Digite inicio del ciclo : "))
fin = (input("Digite fin del ciclo : "))
# Out:
# Digite inicio del ciclo : 1
# Digite fin del ciclo : 9

# %%
# Segundo ciclo
for inicio in range(10):
   print("Usted va en la vuelta número : ",inicio)
# Out:
# Usted va en la vuelta número :  0
# Usted va en la vuelta número :  1
# Usted va en la vuelta número :  2
# Usted va en la vuelta número :  3
# Usted va en la vuelta número :  4
# Usted va en la vuelta número :  5
# Usted va en la vuelta número :  6
# Usted va en la vuelta número :  7
# Usted va en la vuelta número :  8
# Usted va en la vuelta número :  9

# %%
# Leer cuantos números voy a capturar, sumar y promediar
numero = 0
suma = 0
cantidad = int(input("Digite cantidad de números : "))
for i in range(cantidad):
  numero = int(input("Digite un número : "))
  suma = suma+numero
print("La suma es : ",suma)
promedio = suma/(i+1)
# Out:
# Digite cantidad de números : 5
# Digite un número : 4
# Digite un número : 6
# Digite un número : 7
# Digite un número : 4
# Digite un número : 8
# La suma es :  29

# %%
suma = 0
for i in range(10):
  #print("i almacena : ", i)
  suma = suma+1
  #print(suma es :, suma)
